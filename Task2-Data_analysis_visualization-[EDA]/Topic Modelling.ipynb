# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy (for lemmatization only)
import spacy

# plotting tools
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
# %matplotlib inline

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# Prepare Stopwords
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from','subject','re','edu','use'])

# %%
# Import Datataset
df = pd.read_csv(r'C:\Users\Lenovo\forward_school\FNI-project\Task2-Data_analysis_visualization-[EDA]\cleaned_lemmatized_tweets_data.csv')
df
# Out:
#      Unnamed: 0                   id                 date  \
# 0             0  1353492222344392707  2021-01-25 07:57:47
# 1             1  1353492195827965952  2021-01-25 07:57:40
# 2             2  1353492090311720960  2021-01-25 07:57:15
# 3             3  1353492059370479617  2021-01-25 07:57:08
# 4             4  1353492005008113665  2021-01-25 07:56:55
# ..          ...                  ...                  ...
# 503         861  1430316314158006274  2021-08-25 07:49:17
# 504         862  1430316301457764353  2021-08-25 07:49:14
# 505         863  1430316275729903629  2021-08-25 07:49:08
# 506         864  1430316167609020423  2021-08-25 07:48:43
# 507         878  1441551800130174981  2021-09-25 07:55:06
#
#                                                  tweet             hashtags  \
# 0         idk bothering alcohol inflation time high rn                   []
# 1    inflation much money means prices rise eventua...                   []
# 2    exerts daily fix talk inflation roll deafening...  ['fomc', 'trading']
# 3    regards michellins explains recent price rises...                   []
# 4    oh mike since clearly unaware inflation levels...                   []
# ..                                                 ...                  ...
# 503  dollar day years  adding inflation make dollar...                   []
# 504  obviously felt inflation gas price increase wh...                   []
# 505  ted sorry never studied history gerald ford wi...                   []
# 506                              inflation running hot                   []
# 507  us losing control rapid decline inflation skyr...                   []
#
#             username  place  geo  timezone  \
# 0    MphoKgosidialwa    NaN  NaN       800
# 1    AllenWi92526840    NaN  NaN       800
# 2     ChrisWeston_PS    NaN  NaN       800
# 3      morejunkfromu    NaN  NaN       800
# 4         apecapital    NaN  NaN       800
# ..               ...    ...  ...       ...
# 503          1noTon1    NaN  NaN       800
# 504      JeffLaBoda6    NaN  NaN       800
# 505        TxMelinda    NaN  NaN       800
# 506         mawfunx2    NaN  NaN       800
# 507     detroitotaku    NaN  NaN       800
#
#                                            parse_tweet
# 0            idk bother alcohol inflation time high rn
# 1    inflation much money mean price rise eventuall...
# 2    exert daily fix talk inflation roll deafen exu...
# 3    regard michellin explain recent price rise inf...
# 4    oh mike since clearly unaware inflation level ...
# ..                                                 ...
# 503  dollar day year   add inflation make dollar ye...
# 504  obviously feel inflation gas price increase wh...
# 505  ted sorry never study history gerald ford with...
# 506                                  inflation run hot
# 507  we lose control rapid decline inflation skyroc...
#
# [508 rows x 10 columns]

# %%
# Convert column 'parse tweet' to list
data = df.parse_tweet.values.tolist()

data
# Out:
# ['idk bother alcohol inflation time high rn',
#  'inflation much money mean price rise eventually gas gallon',
#  'exert daily fix talk inflation roll deafen exuberance equity market sin consensus camp see sign real yield rise amp fed tolerate steep curve point usd fomc trading',
#  'regard michellin explain recent price rise inflation aye',
#  'oh mike since clearly unaware inflation level cheat sheet',
#  'inflation trudeau care finance priority feminist gender gay right abortion progressive leftist political correctness wake climate diversity refugee migrant debt deficit radar',
#  'reserve mean anything inflation',
#  'macri try volker thing embrace full dollarization despite borrow enough usd peronist world mmt er lower rate assertion true argentina inflation fall cut rate',
#  'people low skill welfare food stamp raise minimum every state every state need cost living either cause inflation well',
#  'oh yeah buy eth hedge inflation bitcoin oh yeah eth hedge btc uselessness',
#  'hey answer question minimum wage inflation much keep promise easy answer',
#  'true taxis govt waste cause inflation everything cost produce',
#  'fuck boomer update talking point decade municate impossible hur dur solar power petitive inflation luxury apartment cause gentrification',
#  'nein nicht der preis inflation die frage ist falsch es werden ohnehin jede menge nutzlosen kryptow hrungen geschaffen code base opensource bessere frage wird eine neue kryptow hrung vergleichbar bedeutend daf   muss beide stimman technologie und das soziale',
#  'like inflation quote sure everything fine',
#  'lmao we senator pretend inflation mean parison today',
#  'joke matter million people know minimum wage rise year keep pace inflation far get per hour free lunch profit margin control',
#  'lumber price go america since april average new home cost build increase fed chair powell say yesterday see inflation tho lol lumber copper aluminum grocery begin',
#  'always good sign congresspeople know pretend know inflation',
#  'break govt plan exam teacher assess grade base mix coursework mock question exam board check moderation algorithm result    th aug anyone appeal major risk grade inflation pressure teacher mass appeal',
#  'inflation',
#  'oh please asshole know minimum wage keep inflation find odd cook make couple buck hour year later',
#  'go inflation calculator anything take less week take month',
#  'idiot john thune never hear inflation',
#  'investor moditie make collective wager government stimulus plus near zero interest rate fuel demand generate inflation amp weaken   dollar economy rebound pandemic',
#  'runaway inflation yet',
#  'siri inflation',
#  'republicans hear inflation livable wage party claim business market seem understand much economic',
#  'disingenuous pablum say issue sure aware something call inflation matter base wants hear',
#  'wall termine en hausse alors que powell fed rassure sur   inflation',
#  'imagine elect senate seat understand inflation',
#  'wage keep inflation',
#  'bet high grade inflation go criticism teacher incentive pupil honest holdout go disadvantage',
#  'let think thissenjohnthune tweet bear hr salary adjust inflation fightfor minimumwage',
#  'okay instead set adjust inflation',
#  'joe thirty five biden inflation plan tax inflation enough pay obamacare netflix',
#  'furthermore inflation almost certainly high next year last year see look money supply velocity analysis look key macro factor',
#  'lmao keep tell inflation without actually acknowledge origin inflation',
#  'go buy gas lumber beef inflation statistic garbage look price normal stuff people use daily',
#  'think sort pre hyperinflation inflation calm explode year',
#  'inflation adjust return   rd median family   rd median family    start journey   end nearly enough',
#  'consumer confidence rise anz anzbank australia australian bank covid future impact inflation market melbourne outbreak unemployment',
#  'wonder adjust inflation eddie murphy beat bhc shrek movie make lot raw dollar time grant many mcu movie downey appear forgot cast around time back school',
#  'inflation',
#  'ment clearly demonstrate ignorance topic read white paper understand requirement monetary instrument use currency know deterministic static inflation look like hater',
#  'retiree worry inflation may want consider add investment portfolio bankingandfinancenew covid online banking bank business service finance home money loan lease lending market please retweet',
#  'know elon one stand way stock market inflation inevitable see next bull run start doge get',
#  'uphold chairman powell think serve people inflation paper tiger fulfill dual mandate',
#  'still pay subject insane rate inflation americans good example bag fluid saline iv er visit easily run americans bill cost hospital dollar obtain',
#  'tech update billionaire investor ray dalio say rather bitcoin bond inflation surge reveal buy cryptocurrency let discuss digitaltransformation digitalstrategy digitalworkplace',
#  'never self evaluate tip sex harsh environment tough time training soon get road let alone loss age time fly personal failure poverty loneliness traffic inflation',
#  'reason well investment usd rn people want   per year supply drive price inflation cause   supply doge   global currency population growth alone make deflationary',
#  'half produce consume real quantity industry support catch guard quick ramp demand    supply kinda like toilet paper begin pandemic inflation happen',
#  'episode lumber housing car one thing mon rise price today bring episode inflation',
#  'israel palestinian conflict inflation southern border belarus force jet oh nice gatorade',
#  'comment la   nurie mondiale de puce et les difficult approvisionnement entra nent une inflation des prix zdnet tech techno',
#  'michael burry shocking position reveal hyper inflation prep',
#  'inflation protect',
#  'many investor tip accessible professionally manage less volatile way add level inflation protection unlike bitcoin',
#  'look tip reason auction weak investor starting think twice need expensive inflation protection',
#  'transitory bond yield match cpi level like historically inflation due supply chain issue true rise cost',
#  'hey san offense cat ear order sexy belly inflation crap',
#  'make zimbabwe first country sadc co mesa disseminate inflation statistic within day data collection',
#  'literally second later tumble weird fucking bimbofication inflation vore transformation fetish rabbit hole ever',
#  'sjw minimum wage law increase inflation',
#  'save invest steal saving inflation lol',
#  'another problem feed remove last excuse raise nominal interest rate target summer say mean inflation go roof say recipe undershoot inflation target big deal though',
#  'us gnp grow pa next two decade we wage rise war drive tremendous aggregation purchasing power tremendous demand good economist wrong america adapt inflation ease deja vu',
#  'economy week ahead housing consumer spending inflation',
#  'know balloon expensive inflation dadjoke',
#  'inflation though',
#  'panie bet shopper keep pay high price economy money holiday inflation news',
#  'nono trust politician say inflation usual everything fine',
#  'fun fact day inflation adjust disneyland parking cost today instead almost increase cool stuff',
#  'lol oh good inflation rise open border high gas price high unemployment hey worry gender sad',
#  'year current likely continue inflation see right gold absolutely moon',
#  'way inflation go american money new cny',
#  'treefiddy inflation dollartree',
#  'base frequency change inflation rate december say kind',
#  'look northern europe ideal choose transparent taxis oppose stealth taxis fund state inflation cruel tax exact upon unsophisticated stop try condition downtrodden spend little condition instead',
#  'even possible make cartoon good dialogue good message clearly heart behind also slapstick shit like getting smushe inflation cartoon physics cuz bro i d hella make lifegoal',
#  'feed inflation target whenever high unacceptable',
#  'trump ignore covid make thing bad downplaying experience inflation try fact coronna',
#  'noch funktioniert die methode der br llende tiger der sich aber bei genauerer betrachtung als wei   maus entpuppt hervorragend die bauchredn vom diw ihre apokalypsephrasen arbeitspl tzeverlust firmenexodus amp inflation wirken halt immer noch jetzt schluss damit',
#  'inflation everywhere always monetary phenomenon milton friedman',
#  'wage stagnate inflation people less spend shop like aldi prosper grow high street close people increasingly rely food bank sound familiar',
#  'yeah man love hyper inflation',
#  'anyone else recall thanksgive dinner conversation bitcoin bull expect year add dynamic inflation exchange ramp hire',
#  'covid vax biden strong economy bull shit global respectable hahahahaha stand putin sure look like approve pl end afghan war strand americans lower taxis lead inflation soon hyperinflation unite americans ass',
#  'inflation make hat valuable throw',
#  'topic smart people talk deflation vs inflation thread educate quite bit hopefully bring clarity seek',
#  'except talk venezuela ido wrong america live high inflation expect even close hyperinflation',
#  'tlp march inflation mehghanai personal interest',
#  'still hope need anymore stimulus inflation run hot economy strong leave thing alone',
#  'inflation border crisis focus gfys',
#  'monetary policy cause excess demand cause inflation problem port start year ago supply chain disruption monetary policy response cause',
#  'energy inflation',
#  'true hedge   grow inflation',
#  'inflation already control feed helpless',
#  'edible oil price hit record high food inflation treat soar zerohedge jamieoliver foodnetwork wfp foodandwine bflay acfusa',
#  'actually perfect example cost push inflation joe ripple price everything also cause underlie economy slow hence stagflation',
#  'bad news inflation shortage stay',
#  'inflation supply chain shortage southern border control net importer oil',
#  'imagine economy people money   produce widget   widget   day price purchase widget day price rise purchase widget inflation precede increase velocity',
#  'inflation',
#  'inflate asset tax inflation good plan',
#  'ff mais avec   inflation donne plus de les salaire   taient pas les mes les console taient moin ch re proportionnellement mais par contre fallait tre riche pour acheter des jeux perso mes parent en achetaient par max',
#  'nut work gender strategy ppl gunned chicago homeless camp overflow can border crisis mention inflation supply chain disaster truly pathetic administration year',
#  'let see iflondexofficial make wealthy enough ignore inflation',
#  'taxis equal inflation transitory',
#  'inflation well lack good shelf result manpower leave workforce   back get pay stay home',
#  'change behavior due inflation already',
#  'go to hyperinflation anytime soon smart people admit current inflation due money print   one',
#  'hyper inflation economic tool totalitarian regime pierrepoilievreleslynlewisalexpiersonamp',
#  'beat inflation getting crypto rich start londex',
#  'confusing state inflation input byritholtz',
#  'try deflate inflation',
#  'key word yellen predict inflation return normal second half finance money trading debtfree news currency globaltrade investment invest stockmarket wealth realestate market economy',
#  'sleepy creepy turn back oil line lift regulation fossil fuel got rid quick think inflation thing go away',
#  'bination raw material inflation weak consumer spending make third quarter brutal period china panie viabusiness',
#  'inflation see eth wallet thank tolondexofficial',
#  'already way inflation maybe read speak',
#  'former prime minister jean chretien say concerned future canada economy inflation near year high say canada move dark alley exactly sound like vote confidence justin trudeau',
#  'problem government manipulator currency labour constantly lose value unless get raise year   close keep inflation',
#  'happen unrealized capital loss tax credit gt print money gt inflation sooo dumb',
#  'true value save fellow human create wealth build financial product earn yield inflation reduce velocity well price literally save human invest fund longevity research hex hex',
#  'inflation real look thelondexofficial chart',
#  'herepgregmurphy even get inflation fuel   cohort include business folk district concern inflation liberal thing',
#  'say increase minimum wage lead increase purchasing power going get eat inflation',
#  'big news rbnz inflation target central bank generally house price accelerate many country run',
#  'aside obvious disregard inflation amp cost living thune say business small town survive narrow margin course also anyone work small town tell exploitative business barely scrape',
#  'sort money ludicrous sport still go afl grand final people family ticket event plus cheap ticket inflation bitch people bear',
#  'short march back inflation like today policy maker big worry price spike crush economy stimulus policy prove excessive economy normalize risk inflation take lightly',
#  'look metal price coinage long great example dilution coinage inflation cause',
#  'increase interest rate unlikely fed goal maximum employment inflation achieve chairman jerome powell say',
#  'third concern central regulation people ignore maximum inventory concept inflation happen right much trust human',
#  'congress rule debate medium scam corruption violence terror inflation bjp rule modis education smriti iranis certificate beef humein chahiye azaadi poor farmer eat pizza enjoy massage cricket stadium name',
#  'senator familiar concept inflation',
#  'gdp bro inflation rate exchange rate unemployment rate lending rate starter natural resource wealth like talented work craft get far',
#  'today show withjacobgoldstein think decade govt careful much borrow rate go inflation kick point past thinking change',
#  'inflation fear take back seat bank canada put focus job recovery covid market',
#  'remember time chicken get we mint print ton money believe look cock inflation',
#  'think conceptually least set minimum wage percentage state median wage say index inflation make sense',
#  'clearly unaware concept inflation senator john thune everybody',
#  'lolol maybe eli measure discontinued measure cash economy measure saving deposit amp mutual fund still valuable forecast inflation',
#  'know whether laugh hysterically cry futility fed chair jerome powell say money print lead inflation',
#  'inflation increase united nations food amp agriculture organization say global meat price january climb fourth straight month since dec corn future chicago risen soybeans',
#  'short support fund thing go right cover one good whiff inflation bad news item pretty messy stress deal',
#  'commodity price surge raise fear overshoot inflation hedge bet pour fuel sector rally price corn copper oil ft',
#  'senator know inflation work',
#  'supply sider like fed governor wayne angell manley johnson suggest modity price exchange rate yield curve warning incipient inflation fed temper think new discovery still worth watch',
#  'understand relationship inflation oil price shock thank recovery subsidy pms however exchange rate pass spare we oil market bearish oil inflation nigeria pm',
#  'explain wage increase hurt business without factor inflation brain worm shit',
#  'main recur argument raise minimum wage really seem really understand inflation',
#  'goldman stupid commodity growth surge oh inflation modest macro inflation ezerohedge',
#  'australia private sector reap billion bonus fear inflation might start get outta control',
#  'bitch look concept inflation',
#  'remember time sonic fan artificially raise price dollar true look sonic inflation',
#  'pov blind hate poor people forget inflation exist',
#  'political theatre min wage mean sandwich cost gain nothing drive inflation small business pay hs student live home hour part time work',
#  'think depend transition manage relatively gradual heavily focused automation production impact relatively neutral change force occur quickly due geopolitic etc inflation far likely',
#  'dow close near powell reinforce inflation message dc',
#  'agree keep cost live inflation year minimum wage close hour keep peep like mitchie elaine bezos fuckerberg rest uber wealthy',
#  'school choice socioeconomic background amp race allow parent ensure good education possible great equalizer spend   per student yr gov school unreal inflation last yrs competition healthy across society make everyone well',
#  'cool man hear inflation',
#  'big inflation',
#  'say without context inflation cost live real dumb hog turd americans believe sentiment',
#  'good joke beta jb petrol price increase hote hai tb inflation bhi barhti hai nonsense',
#  'year since make hour federal minimum wage high afford pay employee minimum wage still inflation year bad business model',
#  'tell we make   like give damn inflation still make',
#  'idea inflation purely intellectual entire generation moss eco ask toddler even know interest rate',
#  'finance bill check inflation nigeria minister',
#  'either think stupid know inflation historic cost live really stupid sound',
#  'inflation exist suit republican',
#  'roughly year later first job fry cook pay hr thankfully inflation increase cost living since',
#  'help wonder powell regret throw little cold water market morning give today trade multiple chance tell everyone money spigot remain wide open inflation wrong message',
#  'statistic canada hastily revise inflation high concern methodology',
#  'greenback generally weak across board lose steam versus nzd support rbnz bull weak labor market fed indecision inflation fear merge clip optimistic bull confident strong economy month ahead trade',
#  'something tell inflation rise',
#  'obamacare american people need expand help american people minimum wage american people really minimum wage keep inflation get program negativenellie',
#  'velocity money increase velocity circulation indicator transaction individual occur frequently high velocity indicate high degree inflation',
#  'old look inflation cost living increase',
#  'call inflation moron',
#  'til inflation exist calculate see dipshit',
#  'inflation ever hear rise cost live ever hear stop mendacity know lie',
#  'look guy understand inflation today dollar hr like hr',
#  'start work minimum wage hr adjust inflation bear earn hr say earn equivalent hr okay senator own free',
#  'every one draft inflation draft',
#  'also spend money equipment never use blow create inflation',
#  'dollar strength mean rba buy gov debt gov gets spend election win sugar hit get low dollar inflation',
#  'senator question inflation',
#  'remember account inflation bet change thune',
#  'growth keep inflation cut growth change way calculate inflation absolutely count cut social security increase eligibility age result immediate future reduction benefit',
#  'mittee fill management yes man keep bump    inflation panie really sweat give employee raise standard cost living increase end performance raise',
#  'someone please explain inflation senior senator south dakota',
#  'sit we senator pretend know inflation',
#  'someone please explain inflation work asshat',
#  'plz figure yrs nd many time rule consistently year loan corruption economy inflation rate job edu health infrastructure security fp pare everything nd policy prev govmnt nd current gov idk anything plz let know',
#  'sometimes even write one inflation draft',
#  'ok time nearly right article seem grade inflation course trust make professional judgement',
#  'sir inflation south dakota',
#  'perform basic calculation include inflation try pretty depressing beforehand expect senator good math anymore',
#  'gt man live inflation buy bitcoin gt david incorrect ramble reason gt rest us david explanation confusing please simplify gt david research paper',
#  'investing btc want protect tesla usd inflation',
#  'propensity spend highly link source money get money give tend find way saving money earn likely create inflation',
#  'yay inflation',
#  'love many ppl tweet racist classist shit like well give money poor black ppl spend money suppose spend point let sit account gain interest rate slow rate inflation',
#  'belly inflation',
#  'ah late stage capitalism bane every something existence boy howdy management think pizza cupcake helps forget make around hour minimum wage keep inflation amp productivity',
#  'say raise minimum wage cause inflation bullshit boise min wage portland last check rent pretty much',
#  'silver bull run inevitable money success successtip market silvereconomy silver gold metal mining goldmine wealthcreation economy free investment wealth investor inflation finance business saving global financial',
#  'inflation fear make asset price rise',
#  'chill nothing happen nursing home death antifa riot still ongoing job we money print inflation record we debt high tax border crisis drug amp sex trafficking cartel covid test division cancel',
#  'believe something like though measurement basically impossible note ngdp still way target true regardless depend one think inflation ok ngdp target fine',
#  'disasterous international trade forecasting supply demand innovation wonder affect inflation purchase power',
#  'inflation increase stop lie everything facist',
#  'already fiat inflation eat machine want print money fast yesterday',
#  'inflation',
#  'bitcoin also inflation',
#  'yippee hyper inflation everyone',
#  'think cost living increase include crazy food inflation insane rent hike extraordinary people disability factor budget people cerb make much someone odsp',
#  'kink server I m throw draw prompt someone mention spherical inflation never draw seriously give try turn able go failed timeline make really easy get weird friend bellykink',
#  'inflation',
#  'way go glimps inflation every house sell another owner ready buy big payment',
#  'terrific history lesson reminder inflation kind natural calamity',
#  'think post interaction admirable inspiring work job feel sick getting shaft uk gov inflation taxis etc seems never end',
#  'oh   love inflation worsen race relation covid case death crime unsafe city open border',
#  'anyone able school iain inflation',
#  'wage growth keep inflation year doubt another warning sign dem',
#  'son mess around dinner tonight tell late get coal christmas also tell probably get less coal deserve inflation give dirty look',
#  'agree pay people cause inflation inflation mean need pay people',
#  'think say inflation',
#  'price manipulation inflation',
#  'oe prend   e normal la distance ainsi que   inflation du bitcoin fait que viens dans me dm',
#  'inflation drive opportunistic multi national corporation take advantage inflation narrative supply chain issue drive economic amp buy amp buying tantamount approval economy well',
#  'border trump illegal crossing biden   pound fentanyl stop border migrant kid rip family reunite biden pass immi reform amp bbb concerned abt price inflation border put ur lie mouth',
#  'look inflation hedge slow growth btc eth want   money next year ftm sol luna',
#  'measurement es objective cease useful measurement tool booth   inflation',
#  'hehe sweet',
#  'incorrect leader country impose act decrease rate inflation help economy recover brandon do not',
#  'love',
#  'inflation transitory pastor',
#  'specifically think biden cause inflation please lay',
#  'shit biden bill amp policy suck especially afghanistan surrender entice illegal invasion amp inflation',
#  'president nothing inflation go back school',
#  'theta cash tbill new tnt token aim well stablecoin solving follow problem inflation inelasticity diversification main state expansion contraction equilibrium learn mc',
#  'hmmm mention low class homeless even mini home plexe like hong kong benefit liberalsndp try cater middle class screw housing economy inflation',
#  'need credit serviceman kill afghanistan leave behind billion military equipment drive inflation historic level let pandemic rage unnecessary say get control med',
#  'inflation crazy   uav still head spin',
#  'true proof ever increase poverty lift poverty temporary change tomorrow job number good mislead due pandemic amp see high wage inflation cause greed top',
#  'gap rich poor grow sterling devalue brexit vote inflation rise may lead fall sterling flight capital business london country whole face economic pressure',
#  'inflation open border merry christmas present democrats',
#  'grade inflation everywhere',
#  'investor throw cash etf inflation name carbon neutral crypto spot etfs launch canada another bitcoin future etf bite dust bitwise bullish pure bitcoin etf dropping future filing',
#  'low wage high immigration high inflation mean necessary',
#  'christmas need cancel covid year babe able pay credit card inflation',
#  'rely billionaire understand people go pitiful benefit zero hour contract sick pay abuse whilst work hospitality nhs inflation raise national insurance contribution plus sky high gas electricity price',
#  'class help crap biden mount inflation high year unsecured border covid amp ing unabated high gas amp energy price uptick crime smash amp grab theft food price supply chain issue',
#  'rent rise yet measure filter high service inflation ing month viawsj',
#  'biden christmas gift america inflation debt recession build back bankrupt turn another major failure joe biden nancy pelosi read',
#  'st quarter end ole joe qb throw pick southern border vp pick inflation crime respect enemy amp high energy cost quarter leave bad news back qb kamala bad ole joe',
#  'prosperity card stack deck squeeze we   inflation price gouging thing need live consumer labor cost body amp mind exceed hrs day employee dystopia',
#  'anything underlie demand weak many place say demand car china prior chip shortage one consider miss pent demand supply drive inflation make people think economy overheat really',
#  'sugar high come mass amount liquidity pump economy dumb ass politician inflation already',
#  'ahh think misunderstood initial post intend response justification reduce capital gain taxis account inflation economist agree long explanation good luck campaign',
#  'oliveoil lubricant take inflation deep inside',
#  'effect usd inflation interest rate factor greenspan put gt tech bubble look chart production still go new free trade policy change plus war decline precede war',
#  'hope everyone hold money bank know currency inflation',
#  'keep saving monetary inflation definition steal saving',
#  'do not think beta test net good way measure though know say see I m definitely vote either low abolish flr inflation model little much',
#  'look like dollar big spike sideways profit corps reflection dollar devaluation hyperlike inflation',
#  'xrp mmunity xrp inflation goal time xrptothemoon',
#  'biden want limit we lbs red meat one hamburger per month way make red meat unaffordable expect shortage massive inflation',
#  'example nominal gain real gain adjust inflation federal taxis owe counting amts owe state',
#  'inflation',
#  'tiger force create public money control inflation help civil administration corona epidemic far one see tiger force action atifrauf',
#  'deceptive remember tell grow interest think stay grow indexation inflation',
#  'inflation si retaaa',
#  'hilarious remember inflation dear citizen',
#  'seem inflation catch conversion early rice bag rs liberal must happy growth',
#  'primarily    capital gain adjust inflation say buy cash   year later sell   annual inflation period federal tax rate nominal basis real basis',
#  'increase due inflation write law',
#  'aarp report retail drug price continue rise fast inflation pandemic analysis show medicare part spend nearly billion top brand name drug due price increase exceed general inflation rate',
#  'economy seg emergingmarket inflation iran weak economy semiconductor shortfall amp pricing stretch amp delay supplychains china drought amp grain shortfall usd position amp fed activity eft asia econtwitter fintwit inflation',
#  'sound money soon evry system hype inflation step away that s joice part lose winner',
#  'poll percent believe inflation main economic concern americans top taxis unemployment president trump sid good biden destroy economy',
#  'fed always bond market many believe hell break loose couple year interest rate explode inflation begin experience',
#  'low tax inflation tax lol',
#  'like inflation control genius try quell buy add even money economy diluting value even',
#  'current inflation monetary phenomenon either really quite obvious bother look inflation e thing like shipping bottleneck obviously monetary',
#  'good read behind recent rise core inflation via san francisco feed',
#  'cea kv subramanian expect food inflation ease unlock good monsoon',
#  'we market infrastructure deal funny market see positive deal keep shrink size boe leave thing per flag inflation yield usd oil high metal low market invest trade asx stockmarket stock',
#  'inflation covid recover reason inflation rate expect taxis president biden tax plan increase taxis make   top panie pay fare share unemployment rate month month america americans',
#  'great piece inflation apmacro',
#  'like say inflation high taxis problem raise minimum wage anything create inflation near future solution get degree get job move fast able spanish imigrant rest',
#  'rise cost live stagnant wage inflation amp debt get everything everyone want okay afford',
#  'costco nike fedex warn inflation set hit consumerscnbc cost nke fdx',
#  'embrace pedantic side moment say may great example linguistic inflation',
#  'imagine blame biden inflation',
#  'tell inflation rate protect gain still mean walk away well defi risky help risk',
#  'say inflation around since interest rate usdc',
#  'work hard lose money inflation get habit investing month   millionaire time click learn exactly invest aff',
#  'saving account lt annual return inflation also take money start invest invest beat inflation invest patience build wealth time invest fuel early retirement investing make money work',
#  'inflation rise naturally pandemic start slow econmoist think long term issue literally name one president recent year accidentally drone strike civilian border great',
#  'hulk toss bear soon inflation run wild',
#  'shortly small group turkish academic begin publish finding inflation late last year datum begin reflect many turk already suspect price rise twice fast government claim ftaylajean',
#  'joe biden overspending cause inflation make price everything go mention mess make afghanistan totally unnecessary mention barely finish sentence without screw unfit duty',
#  'give building skyscraper bridge etc cheap vs even adjust inflation really much well seem plausible',
#  'supply chain disruption apparent desire world government embark endless spending spree keep inflation concern front center investor precious metal week review september th bullionpmi wir',
#  'nibble away sth slowly reduce something even inflation low nibble away people saving reduce value considerably several year',
#  'inflation temporary price level',
#  'nation literally steal daily basis via inflation wake',
#  'brilliant way break inflation jack rate feed know suicide mission anyone guess end likely ton pain wheelbarrow full cash buy bread hobo ride train',
#  'arizonaaudit joe biden fucking moron change mind fuckbiden gasprice inflation bordercrise afghanistandebacle middleeastcrise bidenremorse impeachbiden covidcrise deltavariant violenceinbluecitie trumpwon bidencheate bidenisaclown',
#  'es incumbent executive amp treasury make debt good either pay tax es debt cover likely print money cover course cause inflation amp devaluation dollar',
#  'heck almost generous lol low rate amp inflation negative return',
#  'see rd th th th th like fish story grow   keep grow never stop stink proud biden enjoy inflation loser',
#  'stupid inflation',
#  'organizational debt due title inflation since mon trope titles cheap thing give employee silent killer',
#  'make big difference vote sad situation see family kid face eviction care people politician rent expensive corporation need pay worker hour keep inflation',
#  'anything literally anything go good right good biden one crisis shit show another spend trillion crime inflation invasion border holy shit man',
#  'link paper inflation mention bygeneraltheorist good amp funniest economics paper read quite rudd author lead quote dashiell hammett amp footnote adorable opening bullet point make cheer',
#  'weird problem obviously people pay enough pay much inflation happen think es wage probably adjust depend standard living area place need hour other get away less',
#  'imagine think democrats legislation already go effect let alone cause inflation rise year',
#  '  storm rider official page nov pm heat protest southern spain metalworker city   diz expand protest effort demand high wage line rapid national inflation around worker begin indefinite',
#  'daughter tooth fall naturally throw american flag blanket amp go put bill pillow wake needless say terrify tale currency inflation crypto federalreserve tezos',
#  'know inflation we thing',
#  'obviously member congress care voter suffer inflation get reelect',
#  'bitcoin fight inflation inflation rise teaching invest earn cryptocurrency bitcoin precise make passive   reach via dm interested learning cryptocurrencie',
#  'interesting look aggregation problem price index overall index inflation quote headline may bear little resemblance price change ponent level',
#  'inflation invisible beast like lie central bank',
#  'right es government print money devalue exist dollar system greedy bastard',
#  'inflation',
#  'inflation we happen alarmed americans',
#  'gallon congratulation rampant inflation',
#  'joe biden spending thanksgiving billionaire house americans suffer effect inflation expensive thanksgiving history think fir work class',
#  'inflation great debter go properly leveraged',
#  'yea happy tp turkey back stock rest entire supply chain follow suit good news inflation folk worry rest thing available price basic need',
#  'carbon tax nothing current inflation example represent cent increase gas start january st hardly inflationary',
#  'erdo gamble economy amid protest rocket inflation turkey',
#  'medium thing biden beto biden cut childhood poverty half get infrastructure bill pass vaccine free available low unemployment create million job wage msm inflation',
#  'berry     mistake steelbeak blueberry inflation story',
#  'berry     mistake steelbeak blueberry inflation story',
#  'dollar store accounting inflation',
#  'yup agree stop lie ur town hall lie many time first say crime went say inflation happen even tho barley afford gas want country well fix border cost',
#  'inflation check panie raise price',
#  'democrats waste tax dollar trillion taxis need go high let count inflation gas food',
#  'berry     mistake steelbeak blueberry inflation story',
#  'bitcoin inflation uncontrollable government eeuu',
#  'die   der gr nen decken gerade die inflation I m lebensmittelbereich ab',
#  'berry     mistake steelbeak blueberry inflation story',
#  'btc ethereum gold solution inflation',
#  '  maine lb lobster minus inflation',
#  'please watch tip generally good lead indicator pm course inflation expectation tip move strongly recent day suggest imminent turn pm',
#  'yeaaaa fistbump especially see see sudden inflation numerous people claim alt different personality help feel people trend feel cool edgy different',
#  'yeah think see inflation go value dollar go gas food price go idiot stop trust guy people',
#  'transitory inflation',
#  'contract care new investor pay inflation staker hex sure early stake get share stake vs usd usually like everything guy pay less',
#  'minimum wage yield cheesecake factory lunch inflation always catch rise wage go hand hand minimum wage countrywide turn minimum wage nyc ca etc cycle never end small business obliterate',
#  'heartbreaking story afghanistan amp also havepotus poll slip amp inflation yay kennedy tonight   darksecretplacerochelleritchiekristinbtatecombatflipflopstombevanrcpjonathanhoenig pet pt onfoxbusiness',
#  'inflation',
#  'plus gas inflation open border strand americans afghanistan shut domestic oil ask opec pump yeah bang job far sleepy joe',
#  'absolutely agree pandemic like war war inflationary disrupt everything early inning pandemic solve amp forget inflation persist',
#  'hope everyone put piece shit select president happy strand afghanistan wide open border covid infect illegal inflation wage say raise corp taxs simply dump consumer pure economic failure go joe',
#  'independent moderate rep dem think even obviously senescent old man well trump people see covid care president see result joe decision eg border inflation big international embarrassment since iran',
#  'bernie inflation kill we',
#  'pass fed finance double qe usd bust election amp lower afterwards double digit inflation pretty much government insanity',
#  'inflation food shortage sure prepare',
#  'one reason increasingly deflation potential inflation effect fade six month ago february something easily forget never anything nuisance instead chart',
#  'listen everymacrovoice podcast one clint cox anddrpippam must pippa always make thing clear early ton thing recently inflation digital currency defi revolution',
#  'want another reason care vaccine inequality contribute inflation unvaccinated manufacturing country like vietnam force shut factory unable meet demand vaccinate world',
#  'national debt print money think national debt primary driver inflation',
#  'inmate use raman money cause inflation jail',
#  'wrong worker family going pay one way another likely though inflation business pass high taxis consumer wait uproar people learn end step cost basis inherit asset cost',
#  '   construction manufacture push wage inflation bbg',
#  'pay big small business return raise price return inflation inflation poor middle class indirect tax es',
#  'thrill find sq foot house current low interest rate high inflation interest rate rise may case hate see many people lose home like',
#  'brexit issue though supply chain wreck covid plenty shortage inflation   know guy point see reply like plaut realize global pandemic',
#  'much hide tax fed say need another trillion erode saving money print less worth yes always inflation matter fast rise live every day pany',
#  'weird people care inflation es buy car toy stuff es feed family unbelievably cruel',
#  'true print money thin air create inflation look educate',
#  'libtard carbon tax everything need live spark inflation slowly make everyone poor',
#  'people blame oil gauge rather fix car blame somebody else car blow problem warn people love tesla elon overprice stock market inflation come',
#  'biden want americans spread vaccination open border inflation hi tax crime thru roof socialist rollout title infrastructure plan leave americans strand foreign land amp cowardiceness action decision time biden resign country',
#  'run inflation calculator wow like today',
#  'yet republicans blame inflation biden see irony',
#  'mon think desire annual retirement   percentage current   factor lifespan inflation medical cost affect future retirement',
#  'biden get endless expensive war death money well trump talk nothing like usually border crisis ongoing inflation due covid supply chain issue oil line hack crime wave start trump continue',
#  'say inflation due biden also make statement trump horrible job number',
#  'solution immigration inflation covid vaccine resistance masks school afghanistan economy eviction much hard   solution blame other point finger spew party rhetoric',
#  'reconciliation bill fail chance inflation drop really biden hope keep house dem get great christmas gift hershel walker run senate take ga table   pickup unless gigantic wave',
#  'gop input dem reckless trillion budget inflation run rampant need turn printing press amp identify real need investment future generation afford irresponsible spending',
#  'inflation ratify spanish conquest aztec inca empire spanish conquistadore hern   cort francisco pizarro well establishment klein venedig german welser family search legendary el dorado ultimately charle',
#  'also I m rlly look idea involve fullbody inflation rn sorry tummy section   fine',
#  'yeah right biden mount inflation high year unsecured border covid amp ing unabated high gas amp energy price uptick crime smash amp grab theft food price supply chain issue',
#  'many thing cause irregular tire wear include inflation tire good news know read tire wear help get vehicle back track',
#  'segwit continue without least double price every year remove build reduction block subsidy want inflation bitcoin keep scam afloat narrative gradually move way approach next halve',
#  'inflation eat month saving second',
#  'stock hd home depot news top blue chip stock handle soar inflation motley fool try good pivot point calculator tradingview stock stockstowatch',
#  'keep hope inflation stop suppose transitory obviously we different mean word biden country right track border secure hope sleep every night',
#  'inflation direct taxation borrow main way government spending fund',
#  'country far biden admn cause mount inflation high year unsecured border covid amp ing unabated high gas amp energy price uptick crime smash amp grab theft food price supply chain issue',
#  'wage growth keep inflation year screw perfectly good rant fact',
#  'turkish people already btc crypto especially since inflation skyrocket matter whatever bill turkish official adopt support',
#  'dude chant fuck joe biden games fan never leave give attention sport wake ass medium tell we vote biden inflation sky rocket obviously clue talk anyways kinda like',
#  'amazing idea pay extra check bag fly separate fast plane like fighter jet sr per mercial flight double pilot double air crew triple convenience inflation bye bye',
#  'actually lot first year much focus inflation democrat infighte progressive go medium grip get pet legislation also help bill promise',
#  'insult inflation live',
#  'omg dude term inflation literally refer expansion credit currency every economic theory one condone policy back school lad',
#  'inflation steal money short',
#  'christmas scratcher loser year brandon planning fight inflation',
#  'ok great nonetheless stable predictable monetary policy remain important keep inflation bay vastly different current monetary fiscal policy',
#  'go drop   shoot back go   end year next summer inflation high',
#  'friend dollar question guess inflation million dollar question think multiple choice',
#  'covid covid covidorigincnnapnprabcnbcnewswspwsj trump usa america fortdetricfederalreserve inflation currency stockmarket long canmexico take inflation overnight rate we still around domino collap',
#  'apologize ability prehend fathom refer current inflation word diligent use exact word instead vague pronoun next time',
#  'indeed fascinating debate thebankofengland prepare risk little inflation devalue government debt eschew rate rise spelt indebted public pay heavy personal price',
#  'look rear view mirror inflation risk   object close appear close hedge bitcoinjoecarlasarebitcointinajimmysongbritishhodltheamericanhodldonnaredelneiljacob',
#  'fed policymaker worry high inflation bacon use car stick around long stay high tho maybe high other highlight depth job hole aim get job every american want one',
#  'biden plan drive big surge inflation nearly year consumer price rise may year ago',
#  'inflation',
#  'inflation really happen',
#  'mean favor raise wage cuz inflation get anyways',
#  'wnba might move bet ticket be not   arena concessions babe floor wit long hair wnba girl get next inflation make supporter sorry bron',
#  'biden buck hit bank account bitcoin stock market inflation go',
#  'inflation horrible everybody need raise',
#  'man insane legit scary stuff inflation',
#  'sure inflation defi token hold transitory',
#  'visit sink estates food bank hospital go critical rape victim get justice interest rate go inflation surge pensioner start die winter poverty ya go to',
#  'keep say rent inflation overall tell',
#  'look like mexico gut hike rate fight inflation be not back do not expect much feed transitory peso soar mexican central bank shock unexpected rate hike',
#  'mindset back late th century makes think poor people work get month truly understand basic economic growth wage inflation',
#  'government think inflation adjust cap maximum asset roth ira pass legislation accordingly people penalize stock appreciate rapidly',
#  'afraid inflation except afraid market reaction aka inflation expectation inflation expectation kill',
#  'boe forecasting inflation peak economic bounce back briefly   soon need raise interest rate',
#  'hear inflation run much hotter economy likely slow fed   fascinating watch unfold dollar remain wildcard see reason veer hypothesis',
#  'job hole inflation fed policymaker split risk view',
#  'half people rent inflation remain half majority mortgage payment   lot cheap low rate deflation new cash full pay buyer get inflation weight get inflation',
#  'mario gibney paul exactly point need context know mean word inflation',
#  'market stay high inflation bring viayoutube',
#  'yep one realize maybe nash argument ideal rate inflation zero',
#  'inflation admit always improve',
#  'fact provide friedman quote mean learn inflation well',
#  'massive inflation horizon happen mean tweet',
#  'tail end correction economy may see major correction later year inflation keep getting push aside price keep go build supply lumber',
#  'give multiple way people use term inflation think context important',
#  'boc seven cpi inflation version include cpix',
#  'interview tidwell jally ultimately agree sumner inflation pointless',
#  'dow future rise point help nike earning key inflation report ahead',
#  'need high inflation rate need high cost living',
#  'love hyper inflation',
#  'joke afaik generally accept definition inflation general rise price good people seem use various way incorrectly interview paul assume nash position base quote take context',
#  'say first stage inflation post war germany stimulate response denial',
#  'inflation many category advice offer way manufacturing entity plan perhaps even take advantage inflation business',
#  'pretty sure say fair know hick work day oh please stop print money inflation go wreck small town lot food grow',
#  'sound like north korea shame one regulate destroy middle class inflation artifical stock market bubble create benefit something else',
#  'obviously exaggeration demand low prior covid believe amount monetary policy lead inflation consumer price bottleneck regulation shoot price copper iron silver gold tin corn beef etc',
#  'top federal reserve official admit soar consumer price may last long anticipate despite fed chair jerome powell insist inflation surge transitory via',
#  'inflation lumber   much grocery twice much get',
#  'inflation',
#  'present admin wala pang pandemic sadsad na ekonomoya natin taas na ng inflation rate sandamakmak na dinagdag ng utang natin consider na mat nakalaan ng budget para sa ibang infrastracture na nakaplano na sa admin njya na ngayon naumpisan sa bagong admin',
#  'inflation start last year round one print biden dem print trillion hyperinflation maybe study money work instead many gender muppet',
#  'good stuff do clown inflation rise high gas food housing price unemployment grow well stagnant people unwilling leave gov teat work yeah great job really screw time',
#  'invest lose money every day inflation big risk placency inaction invest debt debtfree growth millennial taxrich eattherich',
#  'haha pretty good inflation',
#  'inflation make headline fed raise inflation forecast annual wholesale inflation hit one hot level ever plus high cost labor issue continue impact construction new home realestate',
#  'gaslighte we nightmarish inflation already feed deny even exist viaactivistpost',
#  'case wonder adjust inflation barenake lady need million buy love',
#  'obama fy greenbook amp wyden rise act sensible force provision roth exceed certain threshold obama age dependent year old example wyden inflation adjust',
#  'fifth seem lowball number include cash pur say also pur heloc growingly tap investor we ref buyer investor amp pur cash thing market since gfc line inflation covid',
#  'damn expensive know want say inflation ridiculous',
#  'provision   calculation also inflation adjust since inclusion tax code think',
#  'bate inflation inflation potus basically',
#  'wonke inflation risk intermittent fast mon',
#  'american usd go hell via inflation',
#  'inflation rate report monthly risky business lumber use car price already fall',
#  'weimar republic offer generous public service   currency collapse aware spending pay inflation tax poor',
#  'fee move year keep inflation real term get cheap we earn thing cost licence fee cost always despite production cost increase',
#  'happen withscotiabankjm get away thing thing bcuz dept boj charge monitor bank seem know boj customer service charter least evidence centralbankja strength fatca amp inflation',
#  'get ready quick succession post go to try something new upload steelbeak blueberry inflation story image see',
#  'president trump live turningpoint say wait till see real number inflation americafirst',
#  'stock market eventually start slow towards end quarter car back lot gas price e inflation ease housing price e extreme policy sorry',
#  'en cuanto mis fetiche rara vez le digo que algo voy desde lo rom ntico hasta lo sucio desenfrenado aunque tengo favoritos futanari impregnation cum inflation deep troath anal',
#  'fact check inflation increase every month joe biden presidency bidenflation',
#  'opinion wonking inflation risk intermittent fast mon',
#  'objective inflation employment distribution climate inclusion instrument printer',
#  'fairly obvious point gold silver suppress price explode people get fiat system create huge problem fiat currency amongst massive inflation fed allow gold silver metal invest trade',
#  'mean wholesale inflation consumer inflation go way next quarter yes grateful print exist spend',
#  'root inflation much money chase good economist friend milton friedman frequently observe new york times warn inflation also result long lasting damage wage keep',
#  'wage rise inflation socialism',
#  'high wage knock effect price turn everyone else wage effectively go inflation rise worker start strike pay brexit take we back brexiteer happy',
#  'dem put together policy cause problem virus control inflation business find employee big gov cause problem solve',
#  'ihs markit   pmi pretty decent predictor we real gdp well hope correlation way   otherwise we economy really cool way bad possible time forget inflation big problem',
#  'need prevent inflation dollar store remain dollar',
#  'inflation year dollar already',
#  'way inflation go plenty realistic year',
#  'inflation literally hide tax inflation steadily go regardless rebuild crumble infrastructure help everyday americans get work',
#  'neoliberal nonsense issue economy spending cause inflation',
#  'hyperinflation merely really high inflation inflation protection also protect hyperinflation',
#  'important we stop add debt pay cause inflation people afford democrats happy til pletely crush economy get everyone live government handout',
#  'take inflation hit world still back we dollar reason dump buy back low   gain',
#  'senate amp house clear blueprint full package pass senate along party line month maybe feed budge tapering inflation care less pelosi nice yellow dress amp political power ing',
#  'dollar day year   add inflation make dollar year ago worth nothing scoff',
#  'obviously feel inflation gas price increase white privileged',
#  'ted sorry never study history gerald ford withdraw troop vietnam leave pow nixon agree bring home busy inflation war leave behind vietnamese ally also kill biden remove thousand already',
#  'inflation run hot',
#  'we lose control rapid decline inflation skyrocket food gas price shoot moon poverty homelessness continue increase']

# %%
pprint(data[:1])
# Out:
# ['idk bother alcohol inflation time high rn']

# %%
# Tokenize words and cleanup text
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True)) # deacc=True removes punctuations (deaccent)

data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['idk', 'bother', 'alcohol', 'inflation', 'time', 'high', 'rn']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['idk', 'bother', 'alcohol', 'inflation', 'time', 'high', 'rn']

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[doc] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostopwords = remove_stopwords(data_words)

# Create Bigrams
data_words_bigrams = make_bigrams(data_words_nostopwords)

# %%
# initialize spacy 'en_core_web_sm' model and only use tagger to preserve time/memory
nlp = spacy.load('en_core_web_sm',disable=['parser','ner'])

# %%
data_words_bigrams[:1]
# Out:
# [['idk', 'bother', 'alcohol', 'inflation', 'time', 'high', 'rn']]

# %%
# Do lemmatization
data_lemmatized = lemmatization(data_words_bigrams,allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
print(data_lemmatized[:1])
# Out:
# [['bother', 'alcohol', 'inflation', 'time', 'high']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Create Term Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:10]]
# Out:
# [[('alcohol', 1), ('bother', 1), ('high', 1), ('inflation', 1), ('time', 1)],
#  [('inflation', 1),
#   ('eventually', 1),
#   ('gallon', 1),
#   ('gas', 1),
#   ('mean', 1),
#   ('money', 1),
#   ('much', 1),
#   ('price', 1),
#   ('rise', 1)],
#  [('inflation', 1),
#   ('rise', 1),
#   ('amp', 1),
#   ('camp', 1),
#   ('consensus', 1),
#   ('curve', 1),
#   ('daily', 1),
#   ('equity', 1),
#   ('exert', 1),
#   ('exuberance', 1),
#   ('fix', 1),
#   ('fomc', 1),
#   ('market', 1),
#   ('point', 1),
#   ('real', 1),
#   ('roll', 1),
#   ('see', 1),
#   ('sign', 1),
#   ('sin', 1),
#   ('steep', 1),
#   ('talk', 1),
#   ('tolerate', 1),
#   ('trading', 1),
#   ('usd', 1),
#   ('yield', 1)],
#  [('inflation', 1),
#   ('price', 1),
#   ('rise', 1),
#   ('aye', 1),
#   ('explain', 1),
#   ('michellin', 1),
#   ('recent', 1),
#   ('regard', 1)],
#  [('inflation', 1),
#   ('cheat', 1),
#   ('clearly', 1),
#   ('level', 1),
#   ('sheet', 1),
#   ('unaware', 1)],
#  [('inflation', 1),
#   ('abortion', 1),
#   ('care', 1),
#   ('climate', 1),
#   ('correctness', 1),
#   ('debt', 1),
#   ('deficit', 1),
#   ('diversity', 1),
#   ('feminist', 1),
#   ('gay', 1),
#   ('gender', 1),
#   ('leftist', 1),
#   ('migrant', 1),
#   ('political', 1),
#   ('priority', 1),
#   ('progressive', 1),
#   ('radar', 1),
#   ('refugee', 1),
#   ('right', 1),
#   ('trudeau', 1),
#   ('wake', 1)],
#  [('inflation', 1), ('mean', 1)],
#  [('inflation', 1),
#   ('usd', 1),
#   ('argentina', 1),
#   ('assertion', 1),
#   ('borrow', 1),
#   ('cut', 1),
#   ('dollarization', 1),
#   ('embrace', 1),
#   ('enough', 1),
#   ('fall', 1),
#   ('full', 1),
#   ('low', 1),
#   ('peronist', 1),
#   ('rate', 2),
#   ('thing', 1),
#   ('true', 1),
#   ('try', 1),
#   ('volker', 1),
#   ('world', 1)],
#  [('inflation', 1),
#   ('low', 1),
#   ('cause', 1),
#   ('cost', 1),
#   ('food', 1),
#   ('living', 1),
#   ('minimum', 1),
#   ('need', 1),
#   ('people', 1),
#   ('raise', 1),
#   ('skill', 1),
#   ('stamp', 1),
#   ('state', 2),
#   ('welfare', 1),
#   ('well', 1)],
#  [('inflation', 1), ('buy', 1), ('hedge', 1), ('uselessness', 1)]]

# %%
# Building the Topic Model using LDA - fit the model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=id2word, num_topics=5, random_state=100, update_every=1, chunksize=100,passes=10, alpha='auto',per_word_topics=True)

# %%
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.046*"increase" + 0.043*"inflation" + 0.020*"continue" + 0.020*"home" + '
#   '0.019*"shoot" + 0.018*"remove" + 0.017*"moon" + 0.016*"price" + 0.009*"see" '
#   '+ 0.009*"big"'),
#  (1,
#   '0.053*"inflation" + 0.042*"dollar" + 0.034*"year" + 0.029*"back" + '
#   '0.016*"take" + 0.016*"already" + 0.016*"month" + 0.015*"make" + '
#   '0.015*"live" + 0.014*"feed"'),
#  (2,
#   '0.054*"inflation" + 0.029*"get" + 0.026*"gas" + 0.025*"amp" + 0.020*"price" '
#   '+ 0.017*"also" + 0.015*"debt" + 0.015*"people" + 0.015*"government" + '
#   '0.014*"obviously"'),
#  (3,
#   '0.037*"inflation" + 0.022*"hit" + 0.021*"ago" + 0.010*"market" + '
#   '0.010*"policy" + 0.008*"bitcoin" + 0.008*"long" + 0.007*"tell" + '
#   '0.007*"business" + 0.007*"monetary"'),
#  (4,
#   '0.110*"inflation" + 0.019*"add" + 0.018*"pay" + 0.014*"low" + 0.014*"food" '
#   '+ 0.013*"buy" + 0.013*"stop" + 0.012*"day" + 0.012*"leave" + 0.012*"run"')]

# %%
doc_lda = lda_model[corpus] ## transform the model

# %%
# Compute Model Perplexity and Coherence Score
# Judge how too the given topic is

# Perplexity Score. The lower, the better.
print('\nPerplexity: ', lda_model.log_perplexity(corpus))

# Coherence Score. The higher, the better.
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.590123206077279
#
# Coherence Score:  0.4121955896734034

# %%
# Visualize topic-keywords

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word, mds='mmds')
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.238582 -0.032412       1        1  28.586279
# 2      0.082610  0.213407       2        1  24.151988
# 1     -0.215179 -0.146714       3        1  18.646436
# 0     -0.137005  0.120665       4        1  14.745535
# 3      0.030991 -0.154946       5        1  13.869762, topic_info=         Term       Freq      Total Category  logprob  loglift
# 154  increase  40.000000  40.000000  Default  30.0000  30.0000
# 196    dollar  46.000000  46.000000  Default  29.0000  29.0000
# 137       get  42.000000  42.000000  Default  28.0000  28.0000
# 293      back  32.000000  32.000000  Default  27.0000  27.0000
# 145      year  45.000000  45.000000  Default  26.0000  26.0000
# ..        ...        ...        ...      ...      ...      ...
# 83      cause   4.549719  11.518912   Topic5  -5.1864   1.0465
# 9       money   4.457714  22.526204   Topic5  -5.2068   0.3554
# 396    reason   3.567647  16.489041   Topic5  -5.4296   0.4447
# 244     think   3.518478  17.951616   Topic5  -5.4434   0.3458
# 101      keep   3.481802  16.495373   Topic5  -5.4539   0.4199
#
# [227 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 320       1  0.967484      add
# 940       2  0.993270   afford
# 608       5  0.955981      ago
# 1965      1  0.985474     ally
# 615       3  0.984328  already
# ...     ...       ...      ...
# 866       1  0.983699    worth
# 145       2  0.133042     year
# 145       3  0.820424     year
# 145       5  0.022174     year
# 1962      3  0.938734   yellow
#
# [239 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 3, 2, 1, 4])
